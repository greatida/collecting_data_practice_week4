# %%
import pandas as pd

# %%
pd.options.display.max_rows = 200

# %%
film_df = pd.read_csv('C:/Users/idaid/Desktop/CollectingData-AssignmentWeek4/Netflix TV Shows and Movies.csv', delimiter=",", encoding='utf-8')

# %%
film_df.sample(10)
# Out:
#       index        id                                              title  \
# 1239   1239   ts36983                                       Fuller House
# 146     146   tm21596                                         Hollow Man
# 3315   3315  ts250912                   Fear City: New York vs The Mafia
# 3945   3945  tm483602                                             Malang
# 4460   4460  ts296046                                              Lupin
# 514     514   tm49405  Inuyasha the Movie: Affections Touching Across...
# 101     101  tm122434                                       Forrest Gump
# 784     784   tm70528                                           Material
# 276     276   tm93055                                          Grown Ups
# 1389   1389  tm282915                      Fate/Grand Order: First Order
#
#        type                                        description  release_year  \
# 1239   SHOW  D.J. Tanner-Fuller is a widow and mother of th...          2016
# ...

# %%
film_df.info
# Out:
# <bound method DataFrame.info of       index         id                               title   type  \
# 0         0    tm84618                         Taxi Driver  MOVIE
# 1         1   tm127384     Monty Python and the Holy Grail  MOVIE
# 2         2    tm70993                       Life of Brian  MOVIE
# 3         3   tm190788                        The Exorcist  MOVIE
# 4         4    ts22164        Monty Python's Flying Circus   SHOW
# ...     ...        ...                                 ...    ...
# 5278   5278  tm1040816         Momshies! Your Soul is Mine  MOVIE
# 5279   5279  tm1014599                           Fine Wine  MOVIE
# 5280   5280  tm1045018                               Clash  MOVIE
# 5281   5281  tm1098060                      Shadow Parties  MOVIE
# 5282   5282   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     A mentally unstable Vietnam War veteran works ...          1976
# ...

# %%
film_df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'index'}>,
#         <Axes: title={'center': 'release_year'}>],
#        [<Axes: title={'center': 'runtime'}>,
#         <Axes: title={'center': 'imdb_score'}>],
#        [<Axes: title={'center': 'imdb_votes'}>, <Axes: >]], dtype=object)

# %%
film_df.describe(include='all')
# Out:
#               index       id     title   type  \
# count   5283.000000     5283      5283   5283
# unique          NaN     5283      5237      2
# top             NaN  tm84618  The Gift  MOVIE
# freq            NaN        1         3   3407
# mean    2641.000000      NaN       NaN    NaN
# std     1525.215067      NaN       NaN    NaN
# min        0.000000      NaN       NaN    NaN
# 25%     1320.500000      NaN       NaN    NaN
# 50%     2641.000000      NaN       NaN    NaN
# 75%     3961.500000      NaN       NaN    NaN
# max     5282.000000      NaN       NaN    NaN
#
#                                               description  release_year  \
# count                                                5278   5283.000000
# unique                                               5276           NaN
# top     Away from school, during the winter holidays, ...           NaN
# freq                                                    2           NaN
# ...

# %%
film_df.sort_values(by='imdb_score', ascending = False)
# Out:
#       index        id                              title   type  \
# 622     622  ts160526                           Khawatir   SHOW
# 2787   2787  ts265844                           #ABtalks   SHOW
# 229     229       ts4                       Breaking Bad   SHOW
# 3144   3144   ts85398                         Our Planet   SHOW
# 3597   3597   ts90621                       Kota Factory   SHOW
# ...     ...       ...                                ...    ...
# 4782   4782  ts280693  Thomas & Friends: All Engines Go!   SHOW
# 1101   1101  tm171891                         Himmatwala  MOVIE
# 3355   3355  tm839411   Me Against You: Mr. S's Vendetta  MOVIE
# 4648   4648  ts319303                     He's Expecting   SHOW
# 1664   1664  tm549892                            Aerials  MOVIE
#
#                                             description  release_year  \
# 622   A TV show devoted to help young people to be m...          2005
# ...

# %%
film_filter = film_df['type'] == 'MOVIE'

# %%
film_df[film_filter]
# Out:
#       index         id                            title   type  \
# 0         0    tm84618                      Taxi Driver  MOVIE
# 1         1   tm127384  Monty Python and the Holy Grail  MOVIE
# 2         2    tm70993                    Life of Brian  MOVIE
# 3         3   tm190788                     The Exorcist  MOVIE
# 5         5    tm14873                      Dirty Harry  MOVIE
# ...     ...        ...                              ...    ...
# 5277   5277  tm1004011                    Time to Dance  MOVIE
# 5278   5278  tm1040816      Momshies! Your Soul is Mine  MOVIE
# 5279   5279  tm1014599                        Fine Wine  MOVIE
# 5280   5280  tm1045018                            Clash  MOVIE
# 5281   5281  tm1098060                   Shadow Parties  MOVIE
#
#                                             description  release_year  \
# 0     A mentally unstable Vietnam War veteran works ...          1976
# ...

# %%
film_filter = film_df['type'] == 'SHOW'

# %%
film_df[film_filter]
# Out:
#       index        id                               title  type  \
# 4         4   ts22164        Monty Python's Flying Circus  SHOW
# 28       28   ts45948    Monty Python's Fliegender Zirkus  SHOW
# 43       43   ts20681                            Seinfeld  SHOW
# 51       51   ts22082                        Knight Rider  SHOW
# 53       53   ts21715                    Thomas & Friends  SHOW
# ...     ...       ...                                 ...   ...
# 5252   5252  ts309235                      Christmas Flow  SHOW
# 5254   5254  ts307816         Korean Cold Noodle Rhapsody  SHOW
# 5266   5266  ts273317                       Pitta Kathalu  SHOW
# 5275   5275  ts286386                         The Big Day  SHOW
# 5282   5282  ts271048  Mighty Little Bheem: Kite Festival  SHOW
#
#                                             description  release_year  \
# 4     A British sketch comedy series with the shows ...          1969
# ...

# %%
film_df.sort_values(by='imdb_score', ascending = False).head(10)
# Out:
#       index        id                       title  type  \
# 622     622  ts160526                    Khawatir  SHOW
# 2787   2787  ts265844                    #ABtalks  SHOW
# 229     229       ts4                Breaking Bad  SHOW
# 3144   3144   ts85398                  Our Planet  SHOW
# 3597   3597   ts90621                Kota Factory  SHOW
# 245     245    ts3371  Avatar: The Last Airbender  SHOW
# 1346   1346   ts37660                  Reply 1988  SHOW
# 1953   1953   ts78298                   My Mister  SHOW
# 4628   4628  ts296563         Who Rules The World  SHOW
# 3026   3026   ts81120              The Last Dance  SHOW
#
#                                             description  release_year  \
# 622   A TV show devoted to help young people to be m...          2005
# 2787  #ABtalks is a YouTube interview show hosted by...          2018
# 229   When Walter White, a New Mexico chemistry teac...          2008
# ...

# %%
film_df.groupby(['type','age_certification'])['imdb_score'].sum()
# Out:
# type   age_certification
# MOVIE  G                     671.3
#        NC-17                  83.2
#        PG                   1477.6
#        PG-13                2732.5
#        R                    3464.0
# SHOW   TV-14                3166.5
#        TV-G                  457.1
#        TV-MA                5596.2
#        TV-PG                1189.7
#        TV-Y                  615.5
#        TV-Y7                 719.0
# Name: imdb_score, dtype: float64
